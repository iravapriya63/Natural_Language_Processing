# %%
pip install WordCloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python310\lib\site-packages)

# %%
pip install nltk
# Out:
# ...
# WARNING: Ignoring invalid distribution -atplotlib (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python310\lib\site-packages)
# ...

# %%
pip install stopwords
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python310\lib\site-packages)

# %%
#Part A
import nltk
import re
import os
import pandas as pd
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from collections import Counter
from wordcloud import WordCloud
from collections import defaultdict
from nltk.corpus import PlaintextCorpusReader


corpus= '' 
tokenizer = nltk.RegexpTokenizer(r'[^.!?]+')
main_text_corpus = PlaintextCorpusReader(corpus, 'main_texts.txt', sent_tokenizer=tokenizer)
main_text_corpus.fileids()
main_text_corpus.sents()
elements = Counter(eng_news_corpus.words())
elements.most_common(200)
# Out:
# [('.', 11739),
#  (',', 9864),
#  ('the', 6910),
#  ('-', 5847),
#  ('of', 4815),
#  ('and', 4401),
#  ('to', 3996),
#  ('a', 3308),
#  ('(', 3157),
#  (']', 2797),
#  ('"', 2497),
#  (':', 2269),
#  ('is', 2179),
#  ('in', 2070),
#  ('^', 1845),
#  ('security', 1584),
#  ('or', 1488),
#  ('for', 1371),
#  ('that', 1339),
#  ('on', 1305),
#  ('.[', 1264),
#  ('/', 1224),
#  ('[', 1208),
#  (').', 1203),
#  (')', 1169),
#  ('The', 1165),
#  ('be', 1153),
#  ('as', 1128),
#  ('".', 1068),
#  ('from', 1043),
#  ('by', 1011),
#  ('are', 962),
#  ('software', 960),
#  ('edit', 915),
#  ('Security', 896),
#  ('with', 874),
#  ('Retrieved', 864),
#  ('can', 829),
#  ('an', 802),
#  ('system', 797),
#  ("'", 769),
#  (';', 753),
#  ('testing', 729),
#  ('information', 712),
#  ('it', 633),
#  ('10', 626),
#  ('Software', 619),
#  ('–', 607),
#  ('1', 603),
#  ('A', 537),
#  ('not', 514),
#  ('s', 495),
#  ('data', 494),
#  ('Information', 481),
#  ('code', 466),
#  ('doi', 442),
# ...

# %%
#part-b
import nltk
nltk.download('stopwords')
stopwords_list = nltk.corpus.stopwords.words('english')
print("Number of English stop words: ", len(stopwords_list))
print("English stop words: ", ", ".join(stopwords_list))

word_list = []
totalwords = defaultdict(lambda: 0)

words = list(filter(None, [re.sub(r'[^A-Za-z]', '', word) for word in main_text_corpus.words()]))
#words

for k in words:
    if k.lower() not in stopwords_list:            
        word_list.append(k.lower())
        totalwords[k.lower()] += 1;
        
elements = Counter(word_list)
elements.most_common(200)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\irava\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Number of English stop words:  179
# ...

# %%
#part-c
wordcloud = WordCloud(background_color="black", max_words=60)
wordcloud.generate_from_frequencies(totalwords)
plt.figure(figsize=(16,12))
plt.imshow(wordcloud, interpolation='bicubic')
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)
